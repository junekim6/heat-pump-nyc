# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# require('tidyverse')
# library('ggbeeswarm')
# library(geojsonio)
# library(RColorBrewer)
# library(rgdal)
# Out:
# R[write to console]: Error in library(geojsonio) : there is no package called ‘geojsonio’
# Error in library(geojsonio) : there is no package called ‘geojsonio’
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:331, in RMagics.eval(self, code)
#     329 try:
#     330     # Need the newline in case the last line in code is a comment.
# --> 331     value, visible = ro.r("withVisible({%s\n})" % code)
#     332 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     333     # Otherwise next return seems to have copy of error.
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/robjects/__init__.py:459, in R.__call__(self, string)
#     458 p = rinterface.parse(string)
# --> 459 res = self.eval(p)
#     460 return conversion.get_conversion().rpy2py(res)
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/robjects/functions.py:204, in SignatureTranslatedFunction.__call__(self, *args, **kwargs)
#     203         kwargs[r_k] = v
# --> 204 return (super(SignatureTranslatedFunction, self)
#     205         .__call__(*args, **kwargs))
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/robjects/functions.py:127, in Function.__call__(self, *args, **kwargs)
#     126         new_kwargs[k] = cv.py2rpy(v)
# --> 127 res = super(Function, self).__call__(*new_args, **new_kwargs)
#     128 res = cv.rpy2py(res)
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/rinterface_lib/conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/rinterface.py:815, in SexpClosure.__call__(self, *args, **kwargs)
#     814     if error_occured[0]:
# --> 815         raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     816 return res
#
# RRuntimeError: Error in library(geojsonio) : there is no package called ‘geojsonio’
#
#
# During handling of the above exception, another exception occurred:
#
# RInterpreterError                         Traceback (most recent call last)
# Cell In [332], line 1
# ----> 1 get_ipython().run_cell_magic('R', '', "\nrequire('tidyverse')\nlibrary('ggbeeswarm')\nlibrary(geojsonio)\nlibrary(RColorBrewer)\nlibrary(rgdal)\n")
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2417, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2415 with self.builtin_trap:
#    2416     args = (magic_arg_s, cell)
# -> 2417     result = fn(*args, **kwargs)
#    2418 return result
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:868, in RMagics.R(self, line, cell, local_ns)
#     866     if not e.stdout.endswith(e.err):
#     867         print(e.err)
# --> 868     raise e
#     869 finally:
#     870     if self.device in ['png', 'svg']:
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:848, in RMagics.R(self, line, cell, local_ns)
#     846         return_output = False
#     847 else:
# --> 848     text_result, result, visible = self.eval(code)
#     849     text_output += text_result
#     850     if visible:
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:335, in RMagics.eval(self, code)
#     332 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     333     # Otherwise next return seems to have copy of error.
#     334     warning_or_other_msg = self.flush()
# --> 335     raise RInterpreterError(code, str(exception),
#     336                             warning_or_other_msg)
#     337 text_output = self.flush()
#     338 return text_output, value, visible[0]
#
# RInterpreterError: Failed to parse and evaluate line "\nrequire('tidyverse')\nlibrary('ggbeeswarm')\nlibrary(geojsonio)\nlibrary(RColorBrewer)\nlibrary(rgdal)\n".
# R error message: 'Error in library(geojsonio) : there is no package called ‘geojsonio’'

# %%
import pandas as pd

# %%
pd.options.display.max_rows = 30

# %% [markdown]
# ## Heat Pump usage for heating, by state

# %%
# This data is from 2020 RECS Survey Data from U.S. Energy Information Administration 
# Link: https://www.eia.gov/consumption/residential/data/2020/index.php?view=state

df = pd.read_excel("State Space Heating.xlsx", na_values=0)

# %%
df.drop(df.columns[[8, 9, 10, 11]], axis=1, inplace=True)
df.drop([0, 1, 2, 3, 4, 5, 67], axis=0, inplace=True)

# %%
df['Unnamed: 5'] = pd.to_numeric(df['Unnamed: 5'], errors='coerce')

# %%
df.head()
# Out:
#              Preliminary data release date: June 2022 Unnamed: 1 Unnamed: 2  \
# 6   Alabama                                       ...        1.9       0.79
# 7   Alaska                                        ...       0.26       0.09
# 8   Arizona                                       ...       2.68       1.34
# 9   Arkansas                                      ...       1.14       0.63
# 10  California                                    ...      13.18       7.75
#
#    Unnamed: 3 Unnamed: 4  Unnamed: 5 Unnamed: 6 Unnamed: 7
# 6          42        0.8        42.0          N          N
# 7          36          Q         NaN       0.09         36
# 8          50       0.76        28.0          Q          Q
# 9          55       0.26        23.0          N          N
# 10         59       0.65         5.0       0.12          1

# %%
df.rename(columns={
    'Preliminary data release date: June 2022':'state',
    'Unnamed: 1':'pop_in_mill',
    'Unnamed: 2':'furnace_mill',
    'Unnamed: 3':'furnace_pct',
    'Unnamed: 4':'hp_mill',
    'Unnamed: 5':'hp_pct',
    'Unnamed: 6':'steam_hot_water_boiler_mill',
    'Unnamed: 7':'steam_hot_water_boiler_pct'
    }, inplace=True)

# %%
df.state = df.state.str.strip()

# %%
df.state.unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', nan,
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df_states = df[df.state.notnull()]
df_states.hp_pct = df_states.hp_pct.fillna(0)
df_states
# Out:
#             state pop_in_mill furnace_mill furnace_pct hp_mill  hp_pct  \
# 6         Alabama         1.9         0.79          42     0.8    42.0
# 7          Alaska        0.26         0.09          36       Q     0.0
# 8         Arizona        2.68         1.34          50    0.76    28.0
# 9        Arkansas        1.14         0.63          55    0.26    23.0
# 10     California       13.18         7.75          59    0.65     5.0
# ..            ...         ...          ...         ...     ...     ...
# 61       Virginia        3.24         1.71          53    0.98    30.0
# 62     Washington        2.94         1.38          47    0.26     9.0
# 63  West Virginia         0.7         0.37          53    0.14    20.0
# 64      Wisconsin        2.39         1.86          78       Q     0.0
# 65        Wyoming        0.23         0.15          67       Q     0.0
#
#    steam_hot_water_boiler_mill steam_hot_water_boiler_pct
# 6                            N                          N
# 7                         0.09                         36
# 8                            Q                          Q
# 9                            N                          N
# 10                        0.12                          1
# ..                         ...                        ...
# 61                        0.14                          4
# 62                           Q                          Q
# 63                           Q                          Q
# 64                         0.2                          9
# 65                        0.02                          9
#
# [51 rows x 8 columns]

# %%
states_hp = df_states[df_states.columns[[0, 5]]]
states_hp
# Out:
#             state  hp_pct
# 6         Alabama    42.0
# 7          Alaska     0.0
# 8         Arizona    28.0
# 9        Arkansas    23.0
# 10     California     5.0
# ..            ...     ...
# 61       Virginia    30.0
# 62     Washington     9.0
# 63  West Virginia    20.0
# 64      Wisconsin     0.0
# 65        Wyoming     0.0
#
# [51 rows x 2 columns]

# %%
states_hp.to_csv('states_heat_pump.csv', index=False)

# %%
# https://d3-graph-gallery.com/graph/hexbinmap_geo_label.html
# HexMap from D3 Gallery.

# %%
# %%R -i has_hp -w 300 -h 300
#
# ny <- has_hp %>% filter(state == "New York")
#
# # ggplot(has_hp) +
# #     aes(x="A", y=heatpump_numeric) +
# #     aes(size=10, color=ifelse(has_hp$state=="New York")) +
# #     geom_beeswarm(cex = 6, method = "swarm")
#
# ggplot(has_hp) +
#   aes(x="A", y=heatpump_numeric) +
#   aes(size=10, color = ifelse(has_hp$state == "New York", "New York", "Other")) +
#   geom_beeswarm(cex = 7) +
#   guides(color = FALSE, size = FALSE)

# %% [markdown]
# ## New York City GHG inventory

# %%
nyc_ghg_df = pd.read_csv("NYC_GHG_Inventory.csv")

# %%
nyc_ghg_df.head(10)
# Out:
#                 None                    Unnamed: 1       Unnamed: 2  \
# 0               None                           NaN              NaN
# 1  (Sectors, Sector)             (Category, Label)  (Source, Label)
# 2  Stationary Energy  Commercial and Institutional      #2 fuel oil
# 3  Stationary Energy  Commercial and Institutional      #4 fuel oil
# 4  Stationary Energy  Commercial and Institutional      #6 fuel oil
# 5  Stationary Energy  Commercial and Institutional          Biofuel
# 6  Stationary Energy  Commercial and Institutional      Electricity
# 7  Stationary Energy  Commercial and Institutional      Natural gas
# 8  Stationary Energy  Commercial and Institutional            Steam
# 9  Stationary Energy                      Fugitive     Fugitive CH4
#
#         Unnamed: 3         CY 2020          CY 2020.1     CY 2020.2  \
# 0              NaN        Consumed              tCO2e  Source MMbtu
# 1  (Source, Units)             NaN                NaN           NaN
# 2           gallon     54975567.11        568777.2173   7662494.544
# 3           gallon     6613124.399        72719.04012   975171.3239
# 4           gallon             0.0                0.0           0.0
# 5           gallon     3652485.184        23.99682766   472193.2845
# 6              kWh   20264309990.0  6489231.882999999   69141825.69
# 7              SCF  110565000000.0        6025296.418   119112053.1
# 8               kg    3936440178.0        329243.5268   8956026.312
# 9               GJ      1038543.86        486842.3118           0.0
#
#   % change from CY 2020 % change from CY 2020.1 % change from CY 2020.2
# 0              Consumed                   tCO2e            Source MMbtu
# 1                   NaN                     NaN                     NaN
# 2                   0.0                     0.0                     0.0
# 3                   0.0                     0.0                     0.0
# 4                   0.0                     0.0                     0.0
# 5                   0.0                     0.0                     0.0
# 6                   0.0                     0.0                     0.0
# 7                   0.0                     0.0                     0.0
# 8                   0.0                     0.0                     0.0
# 9                   0.0                     0.0                     0.0

# %%
nyc_ghg_df.drop(nyc_ghg_df.columns[[6, 7, 8, 9]], axis=1, inplace=True)

# %%
# Rename columns

nyc_ghg_df.columns = ['sector', 'category', 'source', 'unit', 'consumed', 'tCo2e']

# %%
# Drop rows without values

nyc_ghg_df.drop([0, 1], axis=0, inplace=True)

# %%
nyc_ghg_df.head(10)
# Out:
#                sector                        category        source    unit  \
# 2   Stationary Energy    Commercial and Institutional   #2 fuel oil  gallon
# 3   Stationary Energy    Commercial and Institutional   #4 fuel oil  gallon
# 4   Stationary Energy    Commercial and Institutional   #6 fuel oil  gallon
# 5   Stationary Energy    Commercial and Institutional       Biofuel  gallon
# 6   Stationary Energy    Commercial and Institutional   Electricity     kWh
# 7   Stationary Energy    Commercial and Institutional   Natural gas     SCF
# 8   Stationary Energy    Commercial and Institutional         Steam      kg
# 9   Stationary Energy                        Fugitive  Fugitive CH4      GJ
# 10  Stationary Energy  Manufacturing and Construction   #2 fuel oil  gallon
# 11  Stationary Energy  Manufacturing and Construction   #4 fuel oil  gallon
#
#           consumed              tCo2e
# 2      54975567.11        568777.2173
# 3      6613124.399        72719.04012
# 4              0.0                0.0
# 5      3652485.184        23.99682766
# 6    20264309990.0  6489231.882999999
# 7   110565000000.0        6025296.418
# 8     3936440178.0        329243.5268
# 9       1038543.86        486842.3118
# 10     12674152.39        131126.7806
# 11     1424821.369        15667.57799

# %%
nyc_ghg_df.tCo2e = nyc_ghg_df.tCo2e.astype(float)

# %%
co2_by_category_df = pd.DataFrame(nyc_ghg_df.groupby('category')['tCo2e'].sum().reset_index())

# %%
co2_by_category_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  12 non-null     object
#  1   tCo2e     12 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 320.0+ bytes

# %%
co2_by_category_df.to_csv('category_co2.csv', index=False)

# %%
# %%R
#
# # install.packages("treemapify")
# # install.packages("plotly")
# library(treemapify)
# library(ggplot2)
# library(plotly)

# %%
# %%R
#
# df <- read.csv('category_co2.csv')
#
# df
# Out:
#                          category        tCo2e
# 1                        Aviation     1597.586
# 2            Biological treatment     8550.915
# 3    Commercial and Institutional 13485292.082
# 4                        Fugitive   486842.312
# 5                       Landfills  1960325.000
# 6  Manufacturing and Construction  4001339.954
# 7               Marine Navigation    53463.162
# 8                         On-Road 11658979.491
# 9                        Railways   606152.075
# 10                    Residential 16050928.711
# 11                         TOTALS 48444034.859
# 12           Wastewater treatment   130563.572

# %%
# %%R -w 600 -h 300
#
# ggplot(df) +
#     aes(area=tCo2e, fill=category) +
#     geom_treemap()
